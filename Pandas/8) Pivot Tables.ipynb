# %%
import pandas as pd

path = '/home/eltito/repositorios/Curso-NumPy-Pandas-Matplotlib/Online_Retail.csv'
df = pd.read_csv(path, encoding='latin1')

df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  str
#  1   StockCode    541909 non-null  str
#  2   Description  540455 non-null  str
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  str
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  str
# dtypes: float64(2), int64(1), str(5)
# memory usage: 33.1 MB

# %%
pivot_table = pd.pivot_table(df, index = 'Country', columns= 'Stockcode', values= 'Quantity', aggfunc='sum')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 pivot_table = pd.pivot_table(df, index = 'Country', columns= 'Stockcode', values= 'Quantity', aggfunc='sum')
#
# File ~/repositorios/Curso-NumPy-Pandas-Matplotlib/.venv/lib/python3.12/site-packages/pandas/core/reshape/pivot.py:267, in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort, **kwargs)
#     264     table = concat(pieces, keys=keys, axis=1)
#     265     return table.__finalize__(data, method="pivot_table")
# --> 267 table = __internal_pivot_table(
#     268     data,
#     269     values,
#     270     index,
#     271     columns,
#     272     aggfunc,
#     273     fill_value,
#     274     margins,
#     275     dropna,
#     276     margins_name,
#     277     observed,
#     278     sort,
#     279     kwargs,
#     280 )
# ...
